# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/nishapandey823/ThinkStats2/blob/master/donald_trump_(1).ipynb)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import json

# %%
df1 = pd.read_json('C:\\Users\\actions\\Downloads\\2017-11-01.json')
df1.head()
# Out:
#                    id                                               link  \
# 0  925586955978420224  https://www.twitter.com/RepJimmyGomez/statuses...
# 1  925585461354967040  https://www.twitter.com/SenDeanHeller/statuses...
# 2  925584817080582144  https://www.twitter.com/DeanHeller/statuses/92...
# 3  925584185321963520  https://www.twitter.com/DeanHeller/statuses/92...
# 4  925577934680629248  https://www.twitter.com/jaredpolis/statuses/92...
#
#      screen_name              source  \
# 0  RepJimmyGomez  Twitter for iPhone
# 1     DeanHeller           TweetDeck
# 2     DeanHeller           TweetDeck
# 3     DeanHeller           TweetDeck
# 4     jaredpolis  Twitter for iPhone
#
#                                                 text  \
# 0  #game7 We're ready! https://twitter.com/dodger...
# 1  RT @SenDeanHeller Tragic news out of Marigold ...
# 2  @KevinSilsby @POTUS I agree. That's why I'm pu...
# 3  Early detection saves lives, we have to keep w...
# ...

# %%
df2 = pd.read_json('C:\\Users\\actions\\Downloads\\2017-11-02.json')
df2.head()
# Out:
#                    id                                               link  \
# 0  925935873337815040  https://www.twitter.com/RepSwalwell/statuses/9...
# 1  925935761400180736  https://www.twitter.com/TeamCornyn/statuses/92...
# 2  925935663056289792  https://www.twitter.com/BenSasse/statuses/9259...
# 3  925935512061218816  https://www.twitter.com/HurdOnTheHill/statuses...
# 4  925949393806745600  https://www.twitter.com/bradyfortexas/statuses...
#
#      screen_name                  source  \
# 0    RepSwalwell      Twitter for iPhone
# 1     TeamCornyn           Sprout Social
# 2       BenSasse  Twitter for BlackBerry
# 3  HurdOnTheHill            Media Studio
# 4  bradyfortexas      Twitter for iPhone
#
#                                                 text  \
# 0  Let him face 12 New Yorkers. I have faith in t...
# 1  Congrats to the @astros on their 2017 World Se...
# 2  Setting a #worldseries record is cool -- but d...
# 3  From yesterday's Intelligence Committee hearin...
# ...

# %%
df3 = pd.read_json('C:\\Users\\actions\\Downloads\\2017-11-03.json')
df3.head()
# Out:
#                    id                                               link  \
# 0  926307565683859456  https://www.twitter.com/RepRickLarsen/statuses...
# 1  926307153136242688  https://www.twitter.com/RepTedDeutch/statuses/...
# 2  926302040896294912  https://www.twitter.com/RepPaulCook/statuses/9...
# 3  926301911631921152  https://www.twitter.com/tedlieu/statuses/92630...
# 4  926299839977148416  https://www.twitter.com/RepTrentFranks/statuse...
#
#       screen_name               source  \
# 0   RepRickLarsen  Twitter for Android
# 1    RepTedDeutch   Twitter for iPhone
# 2     RepPaulCook   Twitter Web Client
# 3         tedlieu  Twitter for Android
# 4  RepTrentFranks   Twitter for iPhone
#
#                                                 text  \
# 0  DITTO!!!! https://twitter.com/RepRickLarsen/st...
# 1  GOP lawmaker calls for vote on DREAM Act - htt...
# 2  Watch my latest zippo brief including my first...
# 3  @RAMRANTS Depends on how much someone values a...
# ...

# %%
df_row_merged = pd.concat([df1, df2 , df3], ignore_index=True)
df_row_merged
# Out:
#                       id                                               link  \
# 0     925586955978420224  https://www.twitter.com/RepJimmyGomez/statuses...
# 1     925585461354967040  https://www.twitter.com/SenDeanHeller/statuses...
# 2     925584817080582144  https://www.twitter.com/DeanHeller/statuses/92...
# 3     925584185321963520  https://www.twitter.com/DeanHeller/statuses/92...
# 4     925577934680629248  https://www.twitter.com/jaredpolis/statuses/92...
# 5     925575120755806208  https://www.twitter.com/RepMcSally/statuses/92...
# 6     925574931806638080  https://www.twitter.com/BarbaraComstock/status...
# 7     925573894169354240  https://www.twitter.com/RANDCorporation/status...
# 8     925573758873677824  https://www.twitter.com/budget_policy/statuses...
# 9     925573669337870336  https://www.twitter.com/AllInForWA/statuses/92...
# 10    925601799783923712  https://www.twitter.com/SenatorCantwell/status...
# ...

# %%
df1.shape
# Out:
# (3483, 7)

# %%
df2.shape
# Out:
# (3577, 7)

# %%
df3.shape
# Out:
# (2151, 7)

# %%
df_row_merged.shape
# Out:
# (9211, 7)

# %%
3483 + 3577 +2151
# Out:
# 9211

# %%
#RepJayapal["screen_name"]
#df_row_merged = df_row_merged[df_row_merged.screen_name=="RepJimmyGomez"]
#gapminder_2002 = gapminder[gapminder.year == 2002]
#df_row_merged

# %%
df_donald_trump_tweets = df_row_merged[df_row_merged['text'].str.contains("Donald Trump|Donald|Trump")]
df_donald_trump_tweets.head()
# Out:
#                     id                                               link  \
# 9   925573669337870336  https://www.twitter.com/AllInForWA/statuses/92...
# 15  925676381912133632  https://www.twitter.com/MaxineWaters/statuses/...
# 25  925693769583874048  https://www.twitter.com/BennettJohnT/statuses/...
# 26  925693708904919040  https://www.twitter.com/ShaunKing/statuses/925...
# 29  925692861907128320  https://www.twitter.com/TomCottonAR/statuses/9...
#
#        screen_name              source  \
# 9       RepJayapal  Twitter Web Client
# 15    MaxineWaters  Twitter for iPhone
# 25  TeamSheaPorter  Twitter Web Client
# 26     RepDonBeyer  Twitter for iPhone
# 29     TomCottonAR  Twitter for iPhone
#
#                                                  text  \
# 9   RT @AllInForWA Trump/GOP tax plan is a massive...
# 15  Enough is enough! Join our movement: https://s...
# 25  RT @BennettJohnT Bill that established it got ...
# 26  RT @ShaunKing Again, a white man shot FIVE HUN...
# ...

# %%
#df_donald_trump_tweets.shape[""]
df_donald_trump_tweets['time'] = pd.to_datetime(df_donald_trump_tweets['time'], format="%Y-%m-%d")
df_donald_trump_tweets= df_donald_trump_tweets.set_index('time')
# Out:
# C:\Users\actions\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_donald_trump_tweets.user_id.value_counts().head()
# Out:
# 2962868158    25
# 432895323     18
# 584912320     14
# 242836537     12
# 73238146      12
# Name: user_id, dtype: int64

# %%
df_donald_trump_tweets.head()
# Out:
#                                      id  \
# time
# 2017-11-01 04:02:13  925573669337870336
# 2017-11-01 10:50:22  925676381912133632
# 2017-11-01 11:59:27  925693769583874048
# 2017-11-01 11:59:13  925693708904919040
# 2017-11-01 11:55:51  925692861907128320
#
#                                                                   link  \
# time
# 2017-11-01 04:02:13  https://www.twitter.com/AllInForWA/statuses/92...
# 2017-11-01 10:50:22  https://www.twitter.com/MaxineWaters/statuses/...
# 2017-11-01 11:59:27  https://www.twitter.com/BennettJohnT/statuses/...
# 2017-11-01 11:59:13  https://www.twitter.com/ShaunKing/statuses/925...
# 2017-11-01 11:55:51  https://www.twitter.com/TomCottonAR/statuses/9...
#
#                         screen_name              source  \
# time
# 2017-11-01 04:02:13      RepJayapal  Twitter Web Client
# 2017-11-01 10:50:22    MaxineWaters  Twitter for iPhone
# 2017-11-01 11:59:27  TeamSheaPorter  Twitter Web Client
# ...

# %%
df_donald_trump_positive_tweets = df_donald_trump_tweets[df_donald_trump_tweets['text'].str.contains("good|very good|nice|fine|awesome|very nice|amazing|stunning|astounding|excellent|splendid|wonderful|magnificent|superb|sublime|lovely|delightful|pleasant|likeable|agreeable|personable|charming|delightful|amiable|affable|friendly|kindly|genial|congenial|good-natured|engaging|gracious|sympathetic",case=False)]
df_donald_trump_positive_tweets
# Out:
#                                      id  \
# time
# 2017-11-01 11:59:13  925693708904919040
# 2017-11-01 12:03:31  925694790695620608
# 2017-11-01 13:26:56  925715785552744448
# 2017-11-01 14:21:37  925729546632081408
# 2017-11-01 17:25:43  925775874905006080
# 2017-11-01 18:48:14  925796641206145024
# 2017-11-01 18:45:01  925795833664147456
# 2017-11-01 22:30:33  925852590985891840
# 2017-11-01 22:28:33  925852085601443840
# 2017-11-01 23:59:01  925874852409602048
# 2017-11-02 12:49:36  926068777577525248
# 2017-11-02 14:16:08  926090553900589056
# 2017-11-02 15:45:44  926113101732352000
# 2017-11-02 15:22:31  926107260442509312
# 2017-11-02 17:28:09  926138877542305792
# 2017-11-02 18:05:52  926148367729733632
# 2017-11-02 20:02:48  926177793267859456
# 2017-11-02 22:07:25  926209155089788928
# 2017-11-03 09:46:57  926385196894707712
# 2017-11-03 13:37:04  926443108027559936
# 2017-11-03 13:21:07  926439094439305216
# 2017-11-03 14:27:24  926455777677717504
# ...

# %%
df_donald_trump_positive_tweets.shape
# Out:
# (27, 6)

# %%
Donald_trump_Tweet_percentage = 732/92117*100
Donald_trump_Tweet_percentage
# Out:
# 0.7946415970993411

# %%
Pos_Tweet_percentage= 27/732*100
Pos_Tweet_percentage
# Out:
# 3.6885245901639343

# %%
e = df_donald_trump_tweets.user_id.value_counts()
e.head()
# Out:
# 2962868158    25
# 432895323     18
# 584912320     14
# 242836537     12
# 73238146      12
# Name: user_id, dtype: int64

# %%
d= df_donald_trump_positive_tweets.user_id.value_counts()
d
# Out:
# 2962868158            4
# 23022687              3
# 21572351              3
# 432895323             2
# 163570705             1
# 150078976             1
# 240812994             1
# 47747074              1
# 31611298              1
# 249787913             1
# 41363507              1
# 29442313              1
# 942156122             1
# 29201047              1
# 1058717720            1
# 334894942             1
# 17494010              1
# 818975124460335104    1
# 293131808             1
# Name: user_id, dtype: int64

# %%
#for key in set(d.items()) & set(e.items()):
print(e.items())

# %%
new_data
# Out:
# [2962868158,
#  23022687,
#  21572351,
#  432895323,
#  163570705,
#  150078976,
#  240812994,
#  47747074,
#  31611298,
#  249787913,
#  41363507,
#  29442313,
#  942156122,
#  29201047,
#  1058717720,
#  334894942,
#  17494010,
#  818975124460335104,
#  293131808]

# %%
for key,value in e.items():
    print(key, 'corresponds to', value)
# Out:
# 2962868158 corresponds to 25
# 432895323 corresponds to 18
# 584912320 corresponds to 14
# 242836537 corresponds to 12
# 73238146 corresponds to 12
# 223166587 corresponds to 12
# 21572351 corresponds to 12
# 787373558 corresponds to 11
# 242555999 corresponds to 11
# 247486443 corresponds to 10
# 21059255 corresponds to 10
# 942156122 corresponds to 10
# 31122582 corresponds to 9
# 293131808 corresponds to 9
# 246357149 corresponds to 9
# 33530012 corresponds to 9
# 17494010 corresponds to 9
# 29201047 corresponds to 8
# 811313565760163840 corresponds to 8
# 815733290955112448 corresponds to 7
# 476256944 corresponds to 7
# 334894942 corresponds to 7
# 806906355214852096 corresponds to 7
# 3303026415 corresponds to 7
# 404132211 corresponds to 7
# 729177876 corresponds to 7
# 364415553 corresponds to 6
# 1058520120 corresponds to 6
# 14135426 corresponds to 6
# 154139987 corresponds to 6
# 28602948 corresponds to 6
# 814179031956488192 corresponds to 6
# 23593446 corresponds to 6
# ...

# %%
df_donald_trump_tweets.user_id.value_counts().head()
# Out:
# 2962868158    25
# 432895323     18
# 584912320     14
# 242836537     12
# 73238146      12
# Name: user_id, dtype: int64

# %%
array = []
for key , value in d.items():
    print(key,d[key],e[key])
    var = d[key]/e[key]*100
    print(var , "Percentage")
    if var >=50:
        array.append(key)
array
# Out:
# 2962868158 4 25
# 16.0 Percentage
# 23022687 3 3
# 100.0 Percentage
# 21572351 3 12
# 25.0 Percentage
# 432895323 2 18
# 11.11111111111111 Percentage
# 163570705 1 3
# 33.33333333333333 Percentage
# 150078976 1 3
# 33.33333333333333 Percentage
# 240812994 1 3
# 33.33333333333333 Percentage
# 47747074 1 4
# 25.0 Percentage
# 31611298 1 5
# 20.0 Percentage
# 249787913 1 2
# 50.0 Percentage
# 41363507 1 4
# 25.0 Percentage
# 29442313 1 2
# 50.0 Percentage
# 942156122 1 10
# 10.0 Percentage
# 29201047 1 8
# 12.5 Percentage
# 1058717720 1 1
# 100.0 Percentage
# 334894942 1 7
# 14.285714285714285 Percentage
# 17494010 1 9
# 11.11111111111111 Percentage
# 818975124460335104 1 1
# 100.0 Percentage
# 293131808 1 9
# 11.11111111111111 Percentage
# [23022687, 249787913, 29442313, 1058717720, 818975124460335104]

# %%
#df_donald_trump_tweets.resample('H', how={'text':'count'})
a= df_donald_trump_tweets.resample('H' , how = {"text" : "count"})
a
# Out:
# C:\Users\actions\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...)..apply(<func>)
#                      text
# time
# 2017-11-01 04:00:00     1
# 2017-11-01 05:00:00     0
# 2017-11-01 06:00:00     0
# 2017-11-01 07:00:00     0
# 2017-11-01 08:00:00     0
# 2017-11-01 09:00:00     0
# 2017-11-01 10:00:00     1
# 2017-11-01 11:00:00     6
# 2017-11-01 12:00:00     5
# 2017-11-01 13:00:00    12
# 2017-11-01 14:00:00    27
# 2017-11-01 15:00:00    25
# 2017-11-01 16:00:00    18
# 2017-11-01 17:00:00    25
# 2017-11-01 18:00:00    26
# 2017-11-01 19:00:00    25
# 2017-11-01 20:00:00    30
# 2017-11-01 21:00:00    24
# 2017-11-01 22:00:00    22
# 2017-11-01 23:00:00    12
# 2017-11-02 00:00:00     7
# 2017-11-02 01:00:00     4
# 2017-11-02 02:00:00     3
# 2017-11-02 03:00:00     1
# 2017-11-02 04:00:00     0
# 2017-11-02 05:00:00     1
# 2017-11-02 06:00:00     0
# 2017-11-02 07:00:00     0
# ...

# %%
a.groupby(a.text.index.hour).std()
# Out:
#            text
# time
# 0      4.509250
# 1      1.154701
# 2      3.511885
# 3      0.000000
# 4      0.577350
# 5      0.577350
# 6      0.000000
# 7      0.000000
# 8      0.577350
# 9      0.577350
# 10     0.577350
# 11     2.516611
# 12     1.154701
# 13    12.662280
# 14     7.023769
# 15     7.371115
# 16     6.806859
# 17     6.082763
# 18     4.509250
# 19     2.000000
# 20     8.185353
# 21     4.582576
# 22    11.590226
# 23     3.464102

# %%
a.text.value_counts()
# Out:
# 0     13
# 1     12
# 3      5
# 12     4
# 25     3
# 24     3
# 22     3
# 6      3
# 7      3
# 14     2
# 4      2
# 5      2
# 31     2
# 19     2
# 21     2
# 27     2
# 30     1
# 13     1
# 17     1
# 11     1
# 10     1
# 18     1
# 23     1
# 26     1
# 15     1
# Name: text, dtype: int64
